# %% [markdown]
# <a href="https://colab.research.google.com/github/hscrown/seoul_pr/blob/main/merge_dfs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 데이터 로드

# %%
# 인스톨
# !pip install ydata-profiling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.9/357.9 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 10.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 15.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 14.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 17.5 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27080 sha256=3b1d138ccbdbdd6d46a4f7aa0a510bbfdad46e5cc57ab4a5ca68efbce0f9556e
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.13.1
#     Uninstalling seaborn-0.13.1:
#       Successfully uninstalled seaborn-0.13.1
# ...

# %%
# 필요한 패키지 임포트
import requests
import pandas as pd
from ydata_profiling import ProfileReport

# %%
# API 요청 # 17초 소요
start_point = 1
end_point = 1000 # 최대 1000개까지만 호출 할 수 있음
api_key = '57524f76506d656e3732636a52457a'
url1 = f'http://openapi.seoul.go.kr:8088/{api_key}/json/eduCmpltEnt/{start_point}/{end_point}/'
requests.get(url1)

# json 파일로 자료 요청
json1 = requests.get(url1).json()

# %%
# json 파일 확인
json1
json1.keys() # ['eduCmpltEnt']
json1['eduCmpltEnt'].keys() # ['row']
data = json1['eduCmpltEnt']['row'] # 우리가 원하는 dataset
data # 리스트 안에 딕셔너리가 있는 것을 확인
# # # type(data) # list

df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    ENT_NO             ENT_NM   ENT_BUSI_NO     OPEN_DT ENT_OWNER_NM  \
# 0  1166.0    [교육이수중]사과나무인테리어  105-18-84858  2012-02-13          이영우
# 1  1165.0      [교육이수중]금강인테리어  108-01-07153  2006-05-19          강장식
# 2  1164.0  [교육이수중]알플랜(RPLAN)  393-35-00559  2019-07-01          이정환
# 3  1163.0    [교육이수중]공간디자인 지구  478-08-02774  2024-01-29          김가령
# 4  1162.0      [교육이수중]마성종합설비  520-14-02310  2023-11-27          김종필
#
#     ENT_TEL_NO          BIZ_ITEM  HOLD_LCNS  \
# 0  02-703-0477        인테리어, 건설자재         없음
# 1  02-592-5542              인테리어         없음
# 2  393-35-0055              인테리어         없음
# 3  478-08-0277  그 외 기타 건축마무리 공사업         없음
# 4  520-14-0231         가스, 난방공사업  난방공사(제2종)
#
#                                  MAIN_CNSTRCT_FLD_NM  ENT_ADM_CD  \
# 0  방수공사,목공사,창호 및 유리공사,타일공사,도장공사,단열공사,수장공사(도배,마감공사...  1144011100
# 1  목공사,금속공사,지붕 및 홈통공사,창호 및 유리공사,타일공사,도장공사,수장공사(도배...  1162010200
# 2                     창호 및 유리공사,조명공사,기타(설계, 디자인, 감리)  1111010100
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ENT_NO               608 non-null    float64
#  1   ENT_NM               608 non-null    object
#  2   ENT_BUSI_NO          608 non-null    object
#  3   OPEN_DT              608 non-null    object
#  4   ENT_OWNER_NM         608 non-null    object
#  5   ENT_TEL_NO           608 non-null    object
#  6   BIZ_ITEM             608 non-null    object
#  7   HOLD_LCNS            608 non-null    object
#  8   MAIN_CNSTRCT_FLD_NM  608 non-null    object
#  9   ENT_ADM_CD           608 non-null    object
#  10  ENT_ADDR             608 non-null    object
# dtypes: float64(1), object(10)
# memory usage: 52.4+ KB

# %%
# 결측치 처리
# 결측치가 있는지 확인
# print("결측치가 있는 행 개수:", df.isnull().sum()) # 결측치 없음

# %% [markdown]
# # ydata-profiling으로 EDA

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumGothic')

from ydata_profiling import ProfileReport
profile = ProfileReport(df, title="Profiling Report", explorative=True)
profile.to_file("profiling_report.html")
# Out:
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:354: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # pandas 라이브러리로 EDA
