# %% [markdown]
# <a href="https://colab.research.google.com/github/hscrown/seoul_pr/blob/main/EDA_int.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 데이터 로드

# %%
# 인스톨
# !pip install ydata-profiling

# %%
# 필요한 패키지 임포트
import requests
import pandas as pd
from ydata_profiling import ProfileReport

# %%
# API 요청 # 17초 소요
start_point = 1
end_point = 1000 # 최대 1000개까지만 호출 할 수 있음
api_key = '57524f76506d656e3732636a52457a'


# service_key = 'KwVb1UzxSmeWJMT/RH3Aml5WpWKnxIQCdnv7OLsHWmjfHO8BzE5/rfKD141b9lhWMNLpWOky1RzN/IL2bow+6A=='
service_key = 'sX3JWddMWHJxC43fx9mqgcqSsbmAlTpoFTUPbnrE1Db5uVnEAs7gJIL4Z3tzW1u2S6UC+8/go3xYCnG2wDctAQ=='
Authorization = 'Basic ' + service_key

params ={'serviceKey' : service_key, 'Authorization': Authorization}


# 1:집수리교육업체데이터, 2:중랑구, 3:용산구, 4:영등포구, 5:서초구, 6:광진구
url1 = f'http://openapi.seoul.go.kr:8088/{api_key}/json/eduCmpltEnt/{start_point}/{end_point}/'
url2 = f'https://api.odcloud.kr/api/15102655/v1/uddi:5c3c2592-f746-4401-a75d-cb7ca074996a?page={start_point}&perPage={end_point}&returnType=JSON'
url3 = f'https://api.odcloud.kr/api/15101454/v1/uddi:e82806a2-b6ce-4bc5-85ec-874af7581c31?page={start_point}&perPage={end_point}&returnType=JSON'
url4 = f'https://api.odcloud.kr/api/15101063/v1/uddi:4cea2e7f-ddc4-47e0-9dfe-d020a1677216?page={start_point}&perPage={end_point}&returnType=JSON'
url5 = f'https://api.odcloud.kr/api/15101178/v1/uddi:f207d9dc-9d0d-4267-8198-82655003546d?page={start_point}&perPage={end_point}&returnType=JSON'
url6 = f'https://api.odcloud.kr/api/15100869/v1/uddi:ce46ba29-15c9-4e28-a3cb-fbb60790c665?page={start_point}&perPage={end_point}&returnType=JSON'


requests.get(url1)
requests.get(url2)
requests.get(url3)
requests.get(url4)
requests.get(url5)
requests.get(url6)

# json 파일로 자료 요청
json1 = requests.get(url1).json()
json2 = requests.get(url2, params=params).json()
json3 = requests.get(url2, params=params).json()
json4 = requests.get(url4, params=params).json()
json5 = requests.get(url5, params=params).json()
json6 = requests.get(url6, params=params).json()

# %% [markdown]
# # 1:집수리 교육업체데이터

# %%
# json 파일 확인
json1.keys() # ['eduCmpltEnt']
json1['eduCmpltEnt'].keys() # ['row']
data = json1['eduCmpltEnt']['row'] # 우리가 원하는 dataset


df1 = pd.DataFrame(data)

column_kr = {
    'ENT_NO': '시공업체 일련번호',
    'ENT_NM': '업체명',
    'ENT_BUSI_NO': '사업자등록번호',
    'OPEN_DT': '개업일자',
    'ENT_OWNER_NM': '대표자',
    'ENT_TEL_NO': '전화번호',
    'BIZ_ITEM': '사업종목',
    'HOLD_LCNS': '보유면허',
    'MAIN_CNSTRCT_FLD_NM': '주요시공분야',
    'ENT_ADM_CD': '행정동코드',
    'ENT_ADDR': '업체주소'
}
df1.rename(columns=column_kr, inplace=True)
df1.tail()
# Out:
#      시공업체 일련번호           업체명       사업자등록번호        개업일자  대표자          전화번호  \
# 603       31.0       한두레협동조합  110-86-05683  2013-04-05  유명애
# 604       22.0     도성하우징협동조합  347-86-00621  2017-01-05  이상훈  02-6448-2343
# 605       21.0  사회적협동조합 노느매기  529-82-00225  2018-06-29  박상호
# 606       11.0         집수리업체  111-11-11111  2020-12-01  홍길동  02-1245-5454
# 607        1.0            업체  211-55-11447  2020-11-11  홍길동  02-1245-5454
#
#                                   사업종목  보유면허  \
# 603  주택 및 건물 친환경 개보수, 철거, 인테리어, 건물관리 외     -
# 604                          주거용건물건설용역     -
# 605              도배장판 및 실내장식, 시설관리, 목공     -
# 606                               인테리어  타일공사
# 607                                 사업    건설
#
#                                                 주요시공분야       행정동코드  \
# 603  방수공사,목공사,금속공사,지붕 및 홈통공사,창호 및 유리공사,타일공사,도장공사,단열...  1138010400
# 604                                 목공사,창호 및 유리공사,단열공사  1129011100
# 605  방수공사,목공사,금속공사,지붕 및 홈통공사,창호 및 유리공사,타일공사,도장공사,단열...  1156011700
# ...

# %% [markdown]
# # 2:중랑구 인테리어업체현황

# %%
json2.keys() # ['data']
data2 = json2['data']

df2 = pd.DataFrame(data2)
df2.info() # 47행
df2.drop(columns=['연번','조직형태'], inplace=True)
df2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대표자     47 non-null     object
#  1   도로명주소   47 non-null     object
#  2   등록번호    47 non-null     object
#  3   등록일자    47 non-null     object
#  4   업종      47 non-null     object
#  5   업체명     47 non-null     object
#  6   연번      47 non-null     int64
#  7   우편번호    47 non-null     int64
#  8   전화번호    47 non-null     object
#  9   조직형태    47 non-null     object
# dtypes: int64(2), object(8)
# memory usage: 3.8+ KB
#        대표자                                             도로명주소            등록번호  \
# 0      송성환                       서울특별시 중랑구 중랑역로 234 ,2층 (묵동)     강남­09­01­19
# 1      김진희                          서울특별시 중랑구 용마산로 474 (망우동)      중랑­15­1­01
# 2      안정혜  서울특별시 중랑구 망우로75길 19 , 상가동 203호 (망우동, 중랑숲리가아파트상가)      중랑­22­나­05
# ...

# %% [markdown]
# # 3: 용산구

# %%
json3.keys() # ['data']
data3 = json3['data']

df3 = pd.DataFrame(data3)
df3.info() # 47행
df3.drop(columns=['연번','조직형태'], inplace=True)
df3.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대표자     47 non-null     object
#  1   도로명주소   47 non-null     object
#  2   등록번호    47 non-null     object
#  3   등록일자    47 non-null     object
#  4   업종      47 non-null     object
#  5   업체명     47 non-null     object
#  6   연번      47 non-null     int64
#  7   우편번호    47 non-null     int64
#  8   전화번호    47 non-null     object
#  9   조직형태    47 non-null     object
# dtypes: int64(2), object(8)
# memory usage: 3.8+ KB
#        대표자                                             도로명주소            등록번호  \
# 0      송성환                       서울특별시 중랑구 중랑역로 234 ,2층 (묵동)     강남­09­01­19
# 1      김진희                          서울특별시 중랑구 용마산로 474 (망우동)      중랑­15­1­01
# 2      안정혜  서울특별시 중랑구 망우로75길 19 , 상가동 203호 (망우동, 중랑숲리가아파트상가)      중랑­22­나­05
# ...

# %% [markdown]
# # 4:영등포구

# %%
json4.keys() # ['data']
data4 = json4['data']

df4 = pd.DataFrame(data4)
df4.info() # 129행
df4.drop(columns=['번호','지역'], inplace=True)
df4.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대표자     129 non-null    object
#  1   도로명주소   129 non-null    object
#  2   등록번호    129 non-null    object
#  3   등록일자    129 non-null    object
#  4   번호      129 non-null    int64
#  5   업종      129 non-null    object
#  6   업체명     129 non-null    object
#  7   우편번호    129 non-null    int64
#  8   전화번호    128 non-null    object
#  9   지역      129 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 10.2+ KB
#    대표자                                         도로명주소         등록번호        등록일자  \
# 0  박은주      서울특별시 영등포구 버드나루로 50 , 813호(영등포동2가, 리버타워)  영등포20­01­03  2020-05-19
# 1  전은우                         서울특별시 영등포구 당산로36길 9-3  영등포10­01­05  2010-04-09
# 2  조상익  서울특별시 영등포구 영등포로 109, 3층 라-39호(당산동2가,영등포유통상가)  영등포18­01­02  2018-02-23
# ...

# %% [markdown]
# # 5:서초구

# %%
json5.keys() # ['data']
data5 = json5['data']

df5 = pd.DataFrame(data5)
df5.info() # 306행
df5.drop(columns=['번호'], inplace=True)
df5.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대표자     306 non-null    object
#  1   도로명주소   306 non-null    object
#  2   등록번호    306 non-null    object
#  3   등록일자    306 non-null    object
#  4   번호      306 non-null    int64
#  5   업종      306 non-null    object
#  6   업체명     306 non-null    object
#  7   우편번호    306 non-null    int64
#  8   전화번호    306 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 21.6+ KB
#    대표자                                    도로명주소          등록번호        등록일자  \
# 0  김준식  서울특별시 서초구 효령로46길 5， 4층 505호 (서초동， 구진빌딩)  충남천안09­01­02  2009-06-08
# 1  김명수        서울특별시 서초구 동광로12길 120-6 , 5층 (방배동)   서초­20­01­08  2020-03-09
# 2  김경민            서울특별시 서초구 강남대로 311 901호 (서초동)    서초­22­나­03  2022-02-07
# 3  김승철     서울특별시 서초구 강남대로2길 60 , 1층 (양재동, 국일빌딩)   서초­20­01­23  2020-07-31
# ...

# %% [markdown]
# # 6: 광진구

# %%
json6.keys() # ['data']
data6 = json6['data']

df6 = pd.DataFrame(data6)
df6.info() # 60행
df6.drop(columns=['번호','조직형태'], inplace=True)
df6.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대표자     60 non-null     object
#  1   도로명주소   60 non-null     object
#  2   등록번호    60 non-null     object
#  3   등록일자    60 non-null     object
#  4   번호      60 non-null     int64
#  5   업종      60 non-null     object
#  6   업체명     60 non-null     object
#  7   우편번호    59 non-null     float64
#  8   전화번호    60 non-null     object
#  9   조직형태    60 non-null     object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 4.8+ KB
#        대표자                                              도로명주소         등록번호  \
# 0  정준원,송영석  서울특별시 광진구 광나루로56길 85 판매동3층 에이01,에이02,에이03,비13호...  광진­18­01­01
# 1      장천수                       서울특별시 광진구 용마산로7길 37 3층 (중곡동)  광진­18­01­08
# 2      이용주                      서울특별시 광진구 자양로 75 5층(자양동,삼원빌딩)  광진­16­01­06
# ...

# %% [markdown]
# # DataFrame 합치기

# %%
print("인테리어교육이수업체:",df1.columns)
print("중랑구:",df2.columns)
print("용산구:",df3.columns)
print("영등포구:",df4.columns)
print("서초구:",df5.columns)
print("광진구:",df6.columns)
# Out:
# 인테리어교육이수업체: Index(['시공업체 일련번호', '업체명', '사업자등록번호', '개업일자', '대표자', '전화번호', '사업종목', '보유면허',
#        '주요시공분야', '행정동코드', '업체주소'],
#       dtype='object')
# 중랑구: Index(['대표자', '도로명주소', '등록번호', '등록일자', '업종', '업체명', '우편번호', '전화번호'], dtype='object')
# 용산구: Index(['대표자', '도로명주소', '등록번호', '등록일자', '업종', '업체명', '우편번호', '전화번호'], dtype='object')
# 영등포구: Index(['대표자', '도로명주소', '등록번호', '등록일자', '업종', '업체명', '우편번호', '전화번호'], dtype='object')
# 서초구: Index(['대표자', '도로명주소', '등록번호', '등록일자', '업종', '업체명', '우편번호', '전화번호'], dtype='object')
# 광진구: Index(['대표자', '도로명주소', '등록번호', '등록일자', '업종', '업체명', '우편번호', '전화번호'], dtype='object')

# %%
concate_gus = pd.concat([df2, df3, df4, df5, df6], axis=0)
df = pd.merge(df1,concate_gus, on='대표자', how='outer').reset_index(drop=True, inplace=True)

concate_gus.reset_index(drop=True, inplace=True)
concate_gus
# Out:
#          대표자                                             도로명주소  \
# 0        송성환                       서울특별시 중랑구 중랑역로 234 ,2층 (묵동)
# 1        김진희                          서울특별시 중랑구 용마산로 474 (망우동)
# 2        안정혜  서울특별시 중랑구 망우로75길 19 , 상가동 203호 (망우동, 중랑숲리가아파트상가)
# 3    나남순,이영권                  서울특별시 중랑구 봉화산로 121 대화빌딩 9층 (상봉동)
# 4        고필삼     서울특별시 중랑구 용마산로 636 101동 908호(동원베네스트로프트) (신내동)
# ..       ...                                               ...
# 584      심영신                   서울특별시 광진구 아차산로44길 25, 201호(자양동)
# 585      김재순                      서울특별시 광진구 용마산로 119, 3층 (중곡동)
# 586      조원주                   서울특별시 광진구 뚝섬로50길 16, 202호 (자양동)
# 587      김창배                      서울특별시 광진구 뚝섬로47길 45 1층 (자양동)
# 588      박혜정                          서울특별시 광진구 자양로7길 31 (자양동)
#
#                등록번호        등록일자       업종        업체명    우편번호          전화번호
# 0       강남­09­01­19  2009-07-06  실내건축공사업     (주)고운벗  2002.0  02-6407-6402
# ...

# %%
# 등록일자 컬럼을 날짜 타입으로 변경
# concate_gus['등록일자'] = pd.to_datetime(concate_gus['등록일자'],format='%Y-%m-%d')
# 중복 행 제거
concate_gus.drop_duplicates(inplace=True)
concate_gus.reset_index(drop=True, inplace=True)
concate_gus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 542 entries, 0 to 541
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대표자     542 non-null    object
#  1   도로명주소   542 non-null    object
#  2   등록번호    542 non-null    object
#  3   등록일자    542 non-null    object
#  4   업종      542 non-null    object
#  5   업체명     542 non-null    object
#  6   우편번호    541 non-null    float64
#  7   전화번호    541 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 34.0+ KB

# %% [markdown]
# # ydata-profiling으로 EDA

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumGothic')

from ydata_profiling import ProfileReport
profile = ProfileReport(concate_gus, title="Profiling Report", explorative=True)
profile.to_file("report_gus.html")
# Out:
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:354: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/visualisation/utils.py:73: UserWarning: Glyph 50864 (\N{HANGUL SYLLABLE U}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/visualisation/utils.py:73: UserWarning: Glyph 54200 (\N{HANGUL SYLLABLE PYEON}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/visualisation/utils.py:73: UserWarning: Glyph 48264 (\N{HANGUL SYLLABLE BEON}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/visualisation/utils.py:73: UserWarning: Glyph 54840 (\N{HANGUL SYLLABLE HO}) missing from current font.
#   plt.savefig(
# ...

# %% [markdown]
# # pandas 라이브러리로 EDA

# %%
concate_gus.isnull()
concate_gus.isnull().sum()
# Out:
# 대표자      0
# 도로명주소    0
# 등록번호     0
# 등록일자     0
# 업종       0
# 업체명      0
# 우편번호     1
# 전화번호     1
# dtype: int64

# %% [markdown]
# # csv,json 파일로 변환

# %%
concate_gus.to_csv('concate_gus.csv', index=False)
concate_gus.to_json('concate_gus.json', orient='records')
concate_gus.to_excel('concate_gus.xlsx')
