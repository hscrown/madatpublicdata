# %% [markdown]
# <a href="https://colab.research.google.com/github/hscrown/madatpublicdata/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 모듈과 패키지 인스톨과 임포트

# %%
# !pip install surprise

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from surprise import Dataset, Reader
from surprise import KNNWithMeans
from surprise import accuracy
from surprise.model_selection import cross_validate, train_test_split
from surprise.model_selection import GridSearchCV

# %% [markdown]
# # 데이터로드 및 전처리

# %%
df = pd.read_csv('/content/user_place_data_240429.csv')

# %%
# 정수인코딩하기 # 도서관은 0 , 박물관은 1, 공원은 2 로 매핑
muse = pd.read_csv('/content/seoul_museums.csv')
muse = muse[['시설명','위도','경도']]

parks = pd.read_csv('/content/seoul_parks.csv')
parks = parks[['공원명','Y좌표(WGS84)','X좌표(WGS84)']]
# ['시설명','위도','경도']로 컬럼명 변경
parks.columns = ['시설명','위도','경도']

libs = pd.read_csv('/content/seoul_libs.csv')
libs = libs[['도서관명','위도','경도']]
libs.columns = ['시설명','위도','경도']

# df2에 합치기
df2 = pd.concat([muse,parks,libs])

# df2에 Place Type 컬럼 만들고, 도서관은 0, 박물관은 1, 공원은 2로 매핑
df2['Place Type'] = 0
df2.loc[df2['시설명'].isin(muse['시설명']), 'Place Type'] = 1
df2.loc[df2['시설명'].isin(parks['시설명']), 'Place Type'] = 2

# df2 컬럼명 변경
df2.columns = ['Place Name','Latitude','Longitude','Place Type']

# %%
# df에 df2 머지 # 이너조인
df = pd.merge(df, df2, on='Place Name' , how='inner')

# %%
df
# Out:
#       User Id  Place Id  Rating Place Name   Latitude   Longitude  Place Type
# 0        1685        34       1     길동생태공원  37.540394  127.154779           2
# 1        1166        34       5     길동생태공원  37.540394  127.154779           2
# 2         936        34       3     길동생태공원  37.540394  127.154779           2
# 3          82        34       4     길동생태공원  37.540394  127.154779           2
# 4         757        34       1     길동생태공원  37.540394  127.154779           2
# ...       ...       ...     ...        ...        ...         ...         ...
# 4475      482       159       1    중랑상봉도서관  37.593096  127.078711           0
# 4476      717       159       5    중랑상봉도서관  37.593096  127.078711           0
# 4477      785       159       5    중랑상봉도서관  37.593096  127.078711           0
# 4478     2978       159       1    중랑상봉도서관  37.593096  127.078711           0
# 4479      272       159       5    중랑상봉도서관  37.593096  127.078711           0
#
# [4480 rows x 7 columns]

# %%
df.to_csv('KNN-Data.csv', index=False, encoding='utf-8')

# %%
# Surprise 라이브러리를 사용하기 위한 데이터 형태로 변환
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(df[['User Id', 'Place Id', 'Rating']], reader)

# %% [markdown]
# # 모델 트레이닝 및 평가
# - KNNWithMeans는 각 사용자의 평가 경향을 고려한다. 사용자가 주는 평점의 평균을 계산하고, 이를 각 평점에서 빼주어 "평균 조정 평점"을 사용한다.
# - 최근접 이웃 선택: 각 예측을 위해, 알고리즘은 가장 유사한 k개의 이웃을 찾고 이 이웃들의 평점을 이용하여 현재 예측하려는 사용자의 평점을 예측

# %%
# 데이터를 트레이닝 셋과 테스트 셋으로 분리
trainset, testset = train_test_split(data, test_size=0.25, random_state=39)

# KNNWithMeans 모델을 사용하여 트레이닝
model = KNNWithMeans(k=3, sim_options={'name': 'pearson_baseline', 'user_based': True})
model.fit(trainset)

# 테스트 데이터로 평가
predictions = model.test(testset)
accuracy.rmse(predictions)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0940
# 1.094010945729359

# %%
# random_state = 42 RMSE: 1.1496 1.1495527230403806
# random_state=41 RMSE: 1.1386 1.1385928254113178
# 40 , RMSE: 1.2199 1.2199035609764548
# 39, RMSE: 1.0940, 1.094010945729359
# 38, RMSE: 1.2187 1.2186563641857953
# 37, RMSE: 1.1506 1.1505571265027348

# %%
# Suprise라이브러리의 cross-validation 기능이용해서 최적의 k값찾기
# k 값을 다양하게 설정하고 교차 검증 수행
# Results for k=3: Mean RMSE: 1.147337273012189, Mean MAE: 0.7694120979476271
for k in range(1,50):
    model = KNNWithMeans(k=k, sim_options={'name': 'pearson_baseline', 'user_based': True})
    cv_results = cross_validate(model, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
    print(f"Results for k={k}: Mean RMSE: {cv_results['test_rmse'].mean()}, Mean MAE: {cv_results['test_mae'].mean()}")
    # rmse가 최소일때 cv_results출력
    if cv_results['test_rmse'].mean() == min(cv_results['test_rmse']):
        print(f"Best k: {k}")
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.2605  1.1611  1.1346  1.1344  1.1252  1.1632  0.0501
# MAE (testset)     0.8424  0.7632  0.7672  0.7628  0.7507  0.7773  0.0330
# Fit time          0.37    0.39    0.37    0.37    0.38    0.37    0.01
# Test time         0.02    0.02    0.02    0.02    0.02    0.02    0.00
# Results for k=1: Mean RMSE: 1.163168077931933, Mean MAE: 0.7772606947717469
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1837  1.1633  1.1951  1.1396  1.1815  1.1726  0.0194
# MAE (testset)     0.7900  0.7668  0.7854  0.7767  0.7906  0.7819  0.0091
# Fit time          0.37    0.57    0.53    0.54    0.55    0.51    0.07
# Test time         0.02    0.04    0.09    0.05    0.05    0.05    0.02
# Results for k=2: Mean RMSE: 1.1726491831832506, Mean MAE: 0.7819051608983546
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1613  1.1715  1.1356  1.2030  1.1569  1.1657  0.0220
# MAE (testset)     0.7744  0.7889  0.7582  0.8063  0.7697  0.7795  0.0166
# Fit time          0.59    0.68    1.26    0.79    0.66    0.79    0.24
# Test time         0.05    0.06    0.13    0.09    0.04    0.08    0.03
# Results for k=3: Mean RMSE: 1.1656757037470715, Mean MAE: 0.779512248619589
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0978  1.1399  1.2166  1.1725  1.2336  1.1721  0.0497
# MAE (testset)     0.7376  0.7655  0.8070  0.7918  0.8102  0.7824  0.0274
# Fit time          0.75    0.62    0.47    0.46    0.47    0.55    0.11
# Test time         0.05    0.03    0.04    0.03    0.04    0.04    0.01
# Results for k=4: Mean RMSE: 1.1720953084719212, Mean MAE: 0.7824173810715828
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1299  1.1757  1.2171  1.1445  1.1632  1.1661  0.0299
# MAE (testset)     0.7610  0.7888  0.8234  0.7675  0.7606  0.7803  0.0239
# Fit time          0.56    0.50    0.50    0.40    0.45    0.48    0.05
# Test time         0.05    0.05    0.02    0.03    0.04    0.04    0.01
# Results for k=5: Mean RMSE: 1.166086371419368, Mean MAE: 0.7802657660868352
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.2025  1.1320  1.1467  1.1824  1.1917  1.1710  0.0271
# MAE (testset)     0.7962  0.7346  0.7535  0.7797  0.8004  0.7729  0.0253
# Fit time          0.48    0.41    0.37    0.36    0.36    0.40    0.05
# Test time         0.05    0.02    0.02    0.02    0.03    0.03    0.01
# Results for k=21: Mean RMSE: 1.1710457022896583, Mean MAE: 0.7728823788376088
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1598  1.1310  1.1575  1.1778  1.2025  1.1657  0.0237
# MAE (testset)     0.7822  0.7584  0.7560  0.7966  0.8043  0.7795  0.0195
# Fit time          0.36    0.38    0.39    0.36    0.37    0.37    0.01
# Test time         0.03    0.02    0.03    0.03    0.03    0.03    0.00
# Results for k=22: Mean RMSE: 1.1657420800749942, Mean MAE: 0.7794971952981145
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1898  1.1265  1.0946  1.1900  1.2134  1.1629  0.0447
# MAE (testset)     0.8090  0.7520  0.7453  0.7925  0.8057  0.7809  0.0270
# Fit time          0.37    0.37    0.37    0.36    0.37    0.37    0.01
# Test time         0.03    0.03    0.02    0.02    0.02    0.02    0.00
# Results for k=23: Mean RMSE: 1.1628722582736062, Mean MAE: 0.7808994519652525
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1299  1.2012  1.1639  1.1293  1.2300  1.1708  0.0397
# MAE (testset)     0.7577  0.7948  0.7661  0.7480  0.8207  0.7775  0.0266
# Fit time          0.36    0.36    0.37    0.37    0.37    0.37    0.00
# Test time         0.03    0.02    0.03    0.03    0.04    0.03    0.00
# Results for k=24: Mean RMSE: 1.1708489523592904, Mean MAE: 0.7774545361858266
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1895  1.1816  1.2201  1.1301  1.1462  1.1735  0.0320
# MAE (testset)     0.7986  0.7886  0.7902  0.7698  0.7699  0.7834  0.0116
# Fit time          0.38    0.37    0.39    0.37    0.39    0.38    0.01
# Test time         0.02    0.02    0.03    0.02    0.03    0.03    0.00
# Results for k=25: Mean RMSE: 1.1734842609348946, Mean MAE: 0.7834267829703817
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1998  1.1050  1.1770  1.1668  1.2058  1.1709  0.0359
# MAE (testset)     0.7956  0.7580  0.7793  0.7788  0.7921  0.7808  0.0132
# Fit time          0.42    0.48    0.46    0.52    0.41    0.46    0.04
# Test time         0.05    0.06    0.05    0.05    0.02    0.05    0.01
# Results for k=26: Mean RMSE: 1.1708916013484916, Mean MAE: 0.7807529902190125
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1507  1.1814  1.2433  1.1380  1.1780  1.1783  0.0364
# MAE (testset)     0.7753  0.7885  0.8216  0.7649  0.7786  0.7858  0.0194
# Fit time          0.36    0.37    0.37    0.37    0.38    0.37    0.01
# Test time         0.02    0.02    0.03    0.02    0.03    0.03    0.00
# Results for k=27: Mean RMSE: 1.1782773214598858, Mean MAE: 0.7857763651949785
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1426  1.1658  1.1473  1.1646  1.2219  1.1684  0.0283
# MAE (testset)     0.7702  0.7751  0.7768  0.7604  0.8033  0.7772  0.0143
# Fit time          0.37    0.37    0.36    0.37    0.37    0.37    0.01
# Test time         0.02    0.03    0.03    0.03    0.03    0.03    0.00
# Results for k=28: Mean RMSE: 1.1684324638809152, Mean MAE: 0.777173243577714
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1825  1.2267  1.1189  1.2055  1.1095  1.1686  0.0467
# MAE (testset)     0.7865  0.7986  0.7390  0.8085  0.7652  0.7796  0.0249
# Fit time          0.37    0.37    0.37    0.36    0.36    0.37    0.00
# Test time         0.03    0.02    0.03    0.02    0.03    0.03    0.00
# Results for k=29: Mean RMSE: 1.168634210687443, Mean MAE: 0.7795843468667281
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1376  1.1987  1.2221  1.1426  1.1698  1.1742  0.0324
# MAE (testset)     0.7581  0.8117  0.8231  0.7755  0.7650  0.7867  0.0259
# Fit time          0.37    0.36    0.37    0.37    0.37    0.37    0.00
# Test time         0.02    0.02    0.03    0.03    0.02    0.02    0.00
# Results for k=30: Mean RMSE: 1.174153998315467, Mean MAE: 0.7866856849235212
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1134  1.2342  1.0955  1.2434  1.1792  1.1731  0.0605
# MAE (testset)     0.7511  0.8183  0.7331  0.8353  0.7910  0.7857  0.0388
# Fit time          0.37    0.38    0.36    0.37    0.46    0.39    0.04
# Test time         0.02    0.03    0.02    0.02    0.04    0.03    0.01
# Results for k=31: Mean RMSE: 1.1731435318533687, Mean MAE: 0.7857418025877948
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1756  1.1429  1.2105  1.0810  1.1839  1.1588  0.0445
# MAE (testset)     0.8000  0.7556  0.8230  0.7162  0.7962  0.7782  0.0379
# Fit time          0.47    0.49    0.52    0.39    0.37    0.45    0.06
# Test time         0.05    0.05    0.04    0.03    0.03    0.04    0.01
# Results for k=32: Mean RMSE: 1.1587742739942828, Mean MAE: 0.7781987677255495
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1698  1.1787  1.1815  1.0891  1.1726  1.1584  0.0349
# MAE (testset)     0.7918  0.7835  0.7900  0.7186  0.7661  0.7700  0.0273
# Fit time          0.37    0.37    0.37    0.37    0.37    0.37    0.00
# Test time         0.03    0.02    0.02    0.03    0.04    0.03    0.01
# Results for k=33: Mean RMSE: 1.1583709637089945, Mean MAE: 0.7699973402848903
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1503  1.2273  1.1301  1.1861  1.1961  1.1780  0.0343
# MAE (testset)     0.7693  0.8196  0.7513  0.7890  0.7894  0.7837  0.0228
# Fit time          0.36    0.37    0.38    0.37    0.37    0.37    0.01
# Test time         0.04    0.03    0.03    0.02    0.04    0.03    0.01
# Results for k=34: Mean RMSE: 1.177967886946119, Mean MAE: 0.7837068992804502
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1253  1.2089  1.1508  1.1297  1.1992  1.1628  0.0349
# MAE (testset)     0.7656  0.8220  0.7680  0.7407  0.7950  0.7783  0.0278
# Fit time          0.36    0.37    0.38    0.38    0.37    0.37    0.01
# Test time         0.03    0.02    0.03    0.03    0.03    0.03    0.00
# Results for k=35: Mean RMSE: 1.1627627807778889, Mean MAE: 0.7782524025033126
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1964  1.1396  1.2864  1.1403  1.1154  1.1756  0.0614
# MAE (testset)     0.7801  0.7523  0.8481  0.7831  0.7539  0.7835  0.0347
# Fit time          0.37    0.38    0.37    0.36    0.37    0.37    0.00
# Test time         0.03    0.03    0.02    0.02    0.03    0.03    0.00
# Results for k=36: Mean RMSE: 1.1756072004585667, Mean MAE: 0.7835072688696391
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1120  1.1503  1.2110  1.1246  1.2382  1.1672  0.0492
# MAE (testset)     0.7474  0.7707  0.8007  0.7508  0.8149  0.7769  0.0268
# Fit time          0.37    0.36    0.36    0.36    0.38    0.37    0.01
# Test time         0.03    0.03    0.03    0.03    0.03    0.03    0.00
# Results for k=45: Mean RMSE: 1.1672078366028302, Mean MAE: 0.7769029667288064
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1983  1.1762  1.1618  1.1652  1.1459  1.1695  0.0174
# MAE (testset)     0.8062  0.7872  0.7786  0.7639  0.7714  0.7815  0.0146
# Fit time          0.38    0.36    0.38    0.38    0.36    0.37    0.01
# Test time         0.03    0.02    0.03    0.03    0.02    0.03    0.00
# Results for k=46: Mean RMSE: 1.1694900013022316, Mean MAE: 0.781465493456891
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1372  1.1527  1.2001  1.1626  1.2319  1.1769  0.0344
# MAE (testset)     0.7756  0.7636  0.7959  0.7797  0.8266  0.7883  0.0218
# Fit time          0.37    0.48    0.39    0.36    0.36    0.39    0.04
# Test time         0.03    0.03    0.03    0.03    0.03    0.03    0.00
# Results for k=47: Mean RMSE: 1.176888448269442, Mean MAE: 0.7882857338904806
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1817  1.1908  1.1273  1.1532  1.1630  1.1632  0.0223
# MAE (testset)     0.7842  0.7846  0.7433  0.7763  0.7817  0.7740  0.0157
# Fit time          0.36    0.37    0.38    0.40    0.49    0.40    0.05
# Test time         0.02    0.03    0.03    0.05    0.05    0.03    0.01
# Results for k=48: Mean RMSE: 1.1632110198336538, Mean MAE: 0.7740164627251974
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1650  1.1784  1.1089  1.1716  1.2150  1.1678  0.0342
# MAE (testset)     0.7742  0.7791  0.7372  0.8005  0.8091  0.7800  0.0250
# Fit time          0.47    0.49    0.44    0.37    0.36    0.43    0.05
# Test time         0.05    0.05    0.03    0.02    0.03    0.04    0.01
# Results for k=49: Mean RMSE: 1.167771074523174, Mean MAE: 0.7800033601940743

# %% [markdown]
# # 특정 사용자에게 추천 생성

# %%
# 특정 사용자에 대한 추천 생성
user_id = 33
user_items = set([j for (j, _) in trainset.ur[trainset.to_inner_uid(user_id)]])
all_items = set(trainset.all_items())
non_rated_items = all_items - user_items
test_items = [[trainset.to_raw_uid(user_id), trainset.to_raw_iid(item), 5.] for item in non_rated_items]
predictions = model.test(test_items)
top_n_recommendations = sorted(predictions, key=lambda x: x.est, reverse=True)[:5]

# 추천 결과 출력
# print(top_n_recommendations)

# 추천 결과 포매팅 및 출력
formatted_results = []

for prediction in top_n_recommendations:
    formatted_result = f"Place ID: {prediction.iid}, Estimated Rating: {prediction.est}"
    formatted_results.append(formatted_result)

# 포매팅된 결과를 한 줄에 하나씩 출력
for result in formatted_results:
    print(result)

# %%
# 17번 유저의 실제평점과 예측평점 비교
user_id = 17

# 전체 실제평점과 예측 평점
all_ratings = trainset.all_ratings()

print(f"User ID: {user_id}")
print("Actual Ratings:")
for rating in all_ratings:
    if rating[0] == user_id:
        print(f"Place ID: {rating[1]}, Rating: {rating[2]}")

# place id 15,18,26,137 에 대한 예측평점
user_id = 17
item_ids = [15, 18, 26, 137]
predictions = model.test([(user_id, item_id, rating) for item_id in item_ids])

print("Predicted Ratings:")
for prediction in predictions:
    print(f"Place ID: {prediction.iid}, Estimated Rating: {prediction.est}")

# 유저가 평가하지 않은 아이템 추출
user_items = set([j for (j, _) in trainset.ur[trainset.to_inner_uid(user_id)]])
all_items = set(trainset.all_items())
non_rated_items = all_items - user_items
test_items = [[trainset.to_raw_uid(user_id), trainset.to_raw_iid(item), 5.] for item in non_rated_items]
predictions = model.test(test_items)
top_n_recommendations = sorted(predictions, key=lambda x: x.est, reverse=True)[:5]  # 예측 평점 상위 5개 추출

print("Predicted Ratings:")
for prediction in top_n_recommendations:
    print(f"Place ID: {prediction.iid}, Estimated Rating: {prediction.est}")

# Prediction(uid=965, iid=152, r_ui=5.0, est=4.5, details={'actual_k': 0, 'was_impossible': False})

# predictions
# [Prediction(uid=965, iid=152, r_ui=5.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid=965, iid=79, r_ui=5.0, est=4.5, details={'actual_k': 0, 'was_impossible': False})]
# Out:
# User ID: 17
# Actual Ratings:
# Place ID: 15, Rating: 5.0
# Place ID: 18, Rating: 4.0
# Place ID: 26, Rating: 4.0
# Place ID: 137, Rating: 5.0
# Predicted Ratings:
# Place ID: 15, Estimated Rating: 4.989242403018352
# Place ID: 18, Estimated Rating: 4.209302325581396
# Place ID: 26, Estimated Rating: 4.209302325581396
# Place ID: 137, Estimated Rating: 4.209302325581396
# Predicted Ratings:
# Place ID: 70, Estimated Rating: 5
# Place ID: 124, Estimated Rating: 5
# Place ID: 53, Estimated Rating: 5
# Place ID: 175, Estimated Rating: 5
# Place ID: 152, Estimated Rating: 4.5

# %%
# prediction 시각화
import matplotlib.pyplot as plt
# prediction 은 이렇게 생겼음.
# uid=965, iid=152, r_ui=5.0, est=4.5, details={'actual_k': 0, 'was_impossible': False})

# iid가 17일때 실제평점(r_ui) 예측평점(est) 을 시각화
#  matplotlib does not support generators as input
prediction.r_ui
prediction.est

test_items = [[trainset.to_raw_uid(user_id), trainset.to_raw_iid(item), 5.] for item in non_rated_items]
test_items
# Out:
# [[965, 152, 5.0],
#  [965, 79, 5.0],
#  [965, 67, 5.0],
#  [965, 33, 5.0],
#  [965, 72, 5.0],
#  [965, 127, 5.0],
#  [965, 64, 5.0],
#  [965, 88, 5.0],
#  [965, 31, 5.0],
#  [965, 13, 5.0],
#  [965, 25, 5.0],
#  [965, 27, 5.0],
#  [965, 73, 5.0],
#  [965, 82, 5.0],
#  [965, 150, 5.0],
#  [965, 110, 5.0],
#  [965, 133, 5.0],
#  [965, 28, 5.0],
#  [965, 96, 5.0],
#  [965, 158, 5.0],
#  [965, 117, 5.0],
#  [965, 83, 5.0],
#  [965, 131, 5.0],
#  [965, 4, 5.0],
#  [965, 154, 5.0],
#  [965, 134, 5.0],
#  [965, 41, 5.0],
#  [965, 68, 5.0],
#  [965, 37, 5.0],
#  [965, 36, 5.0],
#  [965, 3, 5.0],
#  [965, 43, 5.0],
#  [965, 108, 5.0],
#  [965, 87, 5.0],
#  [965, 14, 5.0],
#  [965, 169, 5.0],
#  [965, 45, 5.0],
#  [965, 129, 5.0],
#  [965, 54, 5.0],
#  [965, 34, 5.0],
#  [965, 56, 5.0],
#  [965, 170, 5.0],
#  [965, 26, 5.0],
#  [965, 89, 5.0],
#  [965, 2, 5.0],
#  [965, 62, 5.0],
#  [965, 91, 5.0],
#  [965, 122, 5.0],
#  [965, 66, 5.0],
#  [965, 142, 5.0],
#  [965, 70, 5.0],
#  [965, 47, 5.0],
#  [965, 86, 5.0],
#  [965, 97, 5.0],
#  [965, 118, 5.0],
#  [965, 16, 5.0],
#  [965, 63, 5.0],
#  [965, 44, 5.0],
#  [965, 121, 5.0],
#  [965, 57, 5.0],
#  [965, 159, 5.0],
#  [965, 138, 5.0],
#  [965, 71, 5.0],
#  [965, 90, 5.0],
#  [965, 1, 5.0],
#  [965, 120, 5.0],
#  [965, 125, 5.0],
#  [965, 19, 5.0],
#  [965, 114, 5.0],
#  [965, 145, 5.0],
#  [965, 51, 5.0],
#  [965, 38, 5.0],
#  [965, 35, 5.0],
#  [965, 143, 5.0],
#  [965, 75, 5.0],
#  [965, 104, 5.0],
#  [965, 115, 5.0],
#  [965, 58, 5.0],
#  [965, 77, 5.0],
#  [965, 174, 5.0],
#  [965, 94, 5.0],
#  [965, 78, 5.0],
#  [965, 123, 5.0],
#  [965, 55, 5.0],
#  [965, 80, 5.0],
#  [965, 165, 5.0],
#  [965, 50, 5.0],
#  [965, 101, 5.0],
#  [965, 157, 5.0],
#  [965, 148, 5.0],
#  [965, 162, 5.0],
#  [965, 22, 5.0],
#  [965, 141, 5.0],
#  [965, 124, 5.0],
#  [965, 59, 5.0],
#  [965, 161, 5.0],
#  [965, 116, 5.0],
#  [965, 40, 5.0],
#  [965, 100, 5.0],
#  [965, 17, 5.0],
#  [965, 107, 5.0],
#  [965, 53, 5.0],
#  [965, 173, 5.0],
#  [965, 0, 5.0],
#  [965, 163, 5.0],
#  [965, 8, 5.0],
#  [965, 42, 5.0],
#  [965, 140, 5.0],
#  [965, 126, 5.0],
#  [965, 151, 5.0],
#  [965, 176, 5.0],
#  [965, 69, 5.0],
#  [965, 12, 5.0],
#  [965, 11, 5.0],
#  [965, 65, 5.0],
#  [965, 10, 5.0],
#  [965, 167, 5.0],
#  [965, 112, 5.0],
#  [965, 149, 5.0],
#  [965, 30, 5.0],
#  [965, 172, 5.0],
#  [965, 32, 5.0],
#  [965, 60, 5.0],
#  [965, 175, 5.0],
#  [965, 130, 5.0],
#  [965, 147, 5.0],
#  [965, 18, 5.0],
#  [965, 46, 5.0],
#  [965, 168, 5.0],
#  [965, 61, 5.0],
#  [965, 85, 5.0],
#  [965, 39, 5.0],
#  [965, 153, 5.0],
#  [965, 171, 5.0]]
